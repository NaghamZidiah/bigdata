# %%
import psycopg2

# %%
## Database connection parameters
conn = psycopg2.connect(
    dbname="dba_db",
    user="postgres",
    password="YOUR_PASSWORD",
    host="localhost",  # Change to your server if needed 127.0.0.1
    port="5432"  # Default PostgreSQL port
)

# %%
 ## Create a cursor to execute queries
cur = conn.cursor()

# %%
## Execute a simple query
cur.execute("SELECT * from users_tbl")

# %%
# print(cur.fetchall())

# %%
## Fetch and print the result
## This method retrieves the next row of a query result set and returns a single sequence, or None if no more rows are available.
print(cur.fetchone())
# Out:
# (1, 'Alice Johnson', 'alice@example.com', 'hashed_password_1', datetime.datetime(2026, 6, 14, 11, 48, 31, 594070))

# %%
print(cur.fetchone())
# Out:
# (2, 'Bob Smith', 'bob@example.com', 'hashed_password_2', datetime.datetime(2026, 6, 14, 11, 48, 31, 594070))

# %%
print(cur.fetchone())
# Out:
# (3, 'Charlie Brown', 'charlie@example.com', 'hashed_password_3', datetime.datetime(2026, 6, 14, 11, 48, 31, 594070))

# %%
print(cur.fetchone())
# Out:
# None

# %%
## Close connection
cur.close()
conn.close()
